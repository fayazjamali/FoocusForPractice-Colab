# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Out:
# Requirement already satisfied: pygit2==1.15.1 in /usr/local/lib/python3.11/dist-packages (1.15.1)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pygit2==1.15.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus

# %%
# !wget -O /content/Fooocus/models/checkpoints/DreamShaper-XL.safetensors https://civitai.com/api/download/models/351306?type=Model&format=SafeTensor&size=full&fp=fp16
# Out:
# --2025-02-21 20:03:54--  https://civitai.com/api/download/models/351306?type=Model
# Resolving civitai.com (civitai.com)... 104.22.18.237, 104.22.19.237, 172.67.12.143, ...
# Connecting to civitai.com (civitai.com)|104.22.18.237|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/53515/dreamshaperxlTurboV2.bHng.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22dreamshaperXL_v21TurboDPMSDE.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250221/us-east-1/s3/aws4_request&X-Amz-Date=20250221T200354Z&X-Amz-SignedHeaders=host&X-Amz-Signature=1b4cba142535a4e7817561a780b33346fb37d16908dc25317ef5842047a29767 [following]
# --2025-02-21 20:03:54--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/53515/dreamshaperxlTurboV2.bHng.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22dreamshaperXL_v21TurboDPMSDE.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250221/us-east-1/s3/aws4_request&X-Amz-Date=20250221T200354Z&X-Amz-SignedHeaders=host&X-Amz-Signature=1b4cba142535a4e7817561a780b33346fb37d16908dc25317ef5842047a29767
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 172.66.1.46, 162.159.141.50, 2a06:98c1:58::12e, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|172.66.1.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6939220250 (6.5G)
# Saving to: ‘/content/Fooocus/models/checkpoints/DreamShaper-XL.safetensors’
#
# /content/Fooocus/mo 100%[===================>]   6.46G  74.0MB/s    in 1m 50s
#
# 2025-02-21 20:05:45 (59.9 MB/s) - ‘/content/Fooocus/models/checkpoints/DreamShaper-XL.safetensors’ saved [6939220250/6939220250]

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 15095 MB, total RAM 12979 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://c73ead80b2fdcd1a5c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_l.text_projection'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.60 seconds
# 2025-02-21 20:49:41.768640: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740170981.793405   13690 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740170981.801142   13690 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-21 20:49:41.833609: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 13624
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://c73ead80b2fdcd1a5c.gradio.live
# Loaded preset: /content/Fooocus/presets/default.json
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 6118265625054801527
# [Parameters] CFG = 2
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_sde - karras
# [Parameters] Steps = 8 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_l.text_projection'}
# left over keys: dict_keys(['conditioner.embedders.0.logit_scale', 'conditioner.embedders.0.text_projection'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.80 seconds
# Base model loaded: /content/Fooocus/models/checkpoints/DreamShaper-XL.safetensors
# VAE loaded: None
# Request to load LoRAs [('Detailed-Perfection-style.safetensors', 0.1), ('Harrlogos-XL.safetensors', 1.0)] for model [/content/Fooocus/models/checkpoints/DreamShaper-XL.safetensors].
# Traceback (most recent call last):
#   File "/content/Fooocus/modules/patch.py", line 465, in loader
#     result = original_loader(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/safetensors/torch.py", line 311, in load_file
#     with safe_open(filename, framework="pt", device=device) as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# safetensors_rust.SafetensorError: Error while deserializing header: HeaderTooLarge
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Fooocus/modules/async_worker.py", line 1471, in worker
#     handler(task)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/async_worker.py", line 1160, in handler
#     tasks, use_expansion, loras, current_progress = process_prompt(async_task, async_task.prompt, async_task.negative_prompt,
#                                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/async_worker.py", line 661, in process_prompt
#     pipeline.refresh_everything(refiner_model_name=async_task.refiner_model_name,
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/default_pipeline.py", line 252, in refresh_everything
#     refresh_loras(loras, base_model_additional_loras=base_model_additional_loras)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/default_pipeline.py", line 139, in refresh_loras
#     model_base.refresh_loras(loras + base_model_additional_loras)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/core.py", line 96, in refresh_loras
#     lora_unmatch = ldm_patched.modules.utils.load_torch_file(lora_filename, safe_load=False)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/ldm_patched/modules/utils.py", line 13, in load_torch_file
#     sd = safetensors.torch.load_file(ckpt, device=device.type)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/patch.py", line 481, in loader
#     raise ValueError(exp)
# ValueError: Error while deserializing header: HeaderTooLarge
# File corrupted: /content/Fooocus/models/loras/Detailed-Perfection-style.safetensors
# Fooocus has tried to move the corrupted file to /content/Fooocus/models/loras/Detailed-Perfection-style.safetensors.corrupted
# You may try again now and Fooocus will download models again.
#
# Total time: 37.62 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 4987647383605577164
# [Parameters] CFG = 2
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_sde - karras
# [Parameters] Steps = 8 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.88 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] (HarroweD text logo), neon green, purple, spikey, splattered, dripping, blood, crown, fog, moon, trees, advanced, detailed, cinematic, light, background, illuminated, vivid, beautiful, pure, rational, artistic, sharp focus, professional, emotional, highly detail, very nice, perfect, fine, colorful, epic, colossal
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] (HarroweD text logo), neon green, purple, spikey, splattered, dripping, blood, crown, fog, moon, trees, fair, highly detailed, epic composition, cinematic light, atmosphere, sharp focus, elegant, intricate, fantastic full color background, dynamic, rich deep colors, ambient, thoughtful, thought, complex, beautiful, enhanced, inspired
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 768)
# Preparation time: 4.10 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.74 seconds
# 100% 8/8 [00:13<00:00,  1.73s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.19 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-21/log.html
# Generating and saving time: 17.34 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# 100% 8/8 [00:13<00:00,  1.66s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-21/log.html
# Generating and saving time: 16.07 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 33.41 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 37.58 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.80 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 7832370820774640471
# [Parameters] CFG = 2
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_sde - karras
# [Parameters] Steps = 8 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] (Rehan Jamali text logo), neon green, purple, spikey, splattered, dripping, blood, crown, fog, moon, trees, fair, pristine, gentle, radiant, flowing, light, detailed, intricate, strong colors, cinematic, winning, highly saturated, deep color, novel, romantic, beautiful, full detail, artistic, sharp, perfect composition
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] (Rehan Jamali text logo), neon green, purple, spikey, splattered, dripping, blood, crown, fog, moon, trees, beautiful, detailed, dynamic, strong, cinematic, breathtaking, attractive, stunning, intricate detail, shiny, very handsome, elegant, luxurious, colorful, coherent, epic, amazing, positive, enhanced, shining, light
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 768)
# Preparation time: 2.10 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.34 seconds
# 100% 8/8 [00:12<00:00,  1.62s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-21/log.html
# Generating and saving time: 16.82 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# 100% 8/8 [00:13<00:00,  1.64s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-21/log.html
# Generating and saving time: 15.84 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 32.66 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 34.81 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.83 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1394245807565052270
# [Parameters] CFG = 2
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_sde - karras
# [Parameters] Steps = 8 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] (REHAN JAMALI) text logo, graffiti, glow, sword, quality, beautiful detailed, pretty, perfect, intricate, illuminated, dramatic, artistic background, professional, cinematic color, sharp focus, fair, true colors, strong, innocent, attractive, confident, inspired, glossy, loving, light, romantic, full, brave, epic, best
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] (REHAN JAMALI) text logo, graffiti, glow, sword, beautiful, perfect, elegant, luxury, elite, dramatic light, cinematic, dynamic composition, charming, majestic, rich deep colors, ambient background, sharp focus, very detailed, intricate, fine detail, clear, pretty, attractive, artistic, color spread, enhanced, amazing, creative
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 768)
# Preparation time: 1.98 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.81 seconds
# 100% 8/8 [00:12<00:00,  1.57s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-21/log.html
# Generating and saving time: 15.98 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.19 seconds
# 100% 8/8 [00:12<00:00,  1.61s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.18 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-21/log.html
# Generating and saving time: 15.69 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 31.67 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 33.71 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.82 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 2564230284490581546
# [Parameters] CFG = 2
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_sde - karras
# [Parameters] Steps = 8 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('Detailed-Perfection-style.safetensors', 2.0), ('Harrlogos-XL.safetensors', 1.0)] for model [/content/Fooocus/models/checkpoints/DreamShaper-XL.safetensors].
# Lora file not found: /content/Fooocus/models/loras/Detailed-Perfection-style.safetensors
# Traceback (most recent call last):
#   File "/content/Fooocus/modules/patch.py", line 465, in loader
#     result = original_loader(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/safetensors/torch.py", line 311, in load_file
#     with safe_open(filename, framework="pt", device=device) as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# safetensors_rust.SafetensorError: Error while deserializing header: HeaderTooLarge
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Fooocus/modules/async_worker.py", line 1471, in worker
#     handler(task)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/async_worker.py", line 1160, in handler
#     tasks, use_expansion, loras, current_progress = process_prompt(async_task, async_task.prompt, async_task.negative_prompt,
#                                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/async_worker.py", line 661, in process_prompt
#     pipeline.refresh_everything(refiner_model_name=async_task.refiner_model_name,
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/default_pipeline.py", line 252, in refresh_everything
#     refresh_loras(loras, base_model_additional_loras=base_model_additional_loras)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/default_pipeline.py", line 139, in refresh_loras
#     model_base.refresh_loras(loras + base_model_additional_loras)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/core.py", line 96, in refresh_loras
#     lora_unmatch = ldm_patched.modules.utils.load_torch_file(lora_filename, safe_load=False)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/ldm_patched/modules/utils.py", line 13, in load_torch_file
#     sd = safetensors.torch.load_file(ckpt, device=device.type)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/patch.py", line 481, in loader
#     raise ValueError(exp)
# ValueError: Error while deserializing header: HeaderTooLarge
# File corrupted: /content/Fooocus/models/loras/Harrlogos-XL.safetensors
# Fooocus has tried to move the corrupted file to /content/Fooocus/models/loras/Harrlogos-XL.safetensors.corrupted
# You may try again now and Fooocus will download models again.
#
# Total time: 0.05 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 3465958667846767740
# [Parameters] CFG = 2
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_sde - karras
# [Parameters] Steps = 8 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.47 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] A 20-year-old Gilr Driving a Car, perfect, ultra-realistic, hyper-detailed, sharp focus, very, detailed, intricate, fine light, real, rich deep colors, dramatic, elegant, luxurious, highly contrasted, color, background bright, cute, magical, cool, magnificent, epic, brilliant, cinematic, symmetry, illuminated, amazing
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] A 20-year-old Gilr Driving a Car, perfect, ultra-realistic, hyper-detailed, beautiful, epic composition, amazing fine detail, color, detailed, pretty, clear background, cinematic, dramatic light, professional, winning, sharp, complex, colors, cool, highly elaborate, very inspirational, ambient, bright, artistic, excellent, dynamic
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 768)
# Preparation time: 3.34 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.78 seconds
# 100% 8/8 [00:12<00:00,  1.55s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-21/log.html
# Generating and saving time: 15.67 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# 100% 8/8 [00:12<00:00,  1.58s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-21/log.html
# Generating and saving time: 15.34 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 31.01 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 34.40 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.81 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 9008756348830043385
# [Parameters] CFG = 2
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_sde - karras
# [Parameters] Steps = 8 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] cinematic film still of, strong attractive, combined light intense gorgeous background created lush very bright glowing real colors, extremely detailed, stunning intricate, fantastic composition, cinematic atmosphere, spectacular fine detail, creative, positive energetic, cheerful, unique, awesome, elegant, luxury, beautiful, dramatic ambient perfect, sharp focus, professional, highly colorful, best, fair, open, shining
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] cinematic film still of, strong attractive, full polished, extremely detailed, sharp focus, fair, clear, crisp, quality, light, artistic, color, intricate detail, cool cinematic colors, striking, iconic, pretty, cute, enhanced, famous, very expressive, complex, friendly, bright, loving, colorful, rational, highly coherent, determined, charming, best
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 768)
# Preparation time: 2.60 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.79 seconds
# 100% 8/8 [00:13<00:00,  1.64s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-21/log.html
# Generating and saving time: 16.47 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# 100% 8/8 [00:13<00:00,  1.69s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-21/log.html
# Generating and saving time: 16.41 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 32.89 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 35.57 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.96 seconds

# %%
# !wget -Lo /content/Fooocus/models/loras/Harrlogos-XL.safetensors https://civitai.com/api/download/models/214296?type=Model&format=SafeTensor
